# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import matplotlib.pyplot as pyp

# %% [markdown]
# # READ DATA

# %%
data = pd.read_csv('UberDataset.csv')
data
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# # DATA ANALYSING

# %%
data.columns
# Out:
# Index(['START_DATE', 'END_DATE', 'CATEGORY', 'START', 'STOP', 'MILES',
#        'PURPOSE'],
#       dtype='object')

# %%
data.CATEGORY.unique()
# Out:
# array(['Business', 'Personal', nan], dtype=object)

# %%
data.PURPOSE.unique()
# Out:
# array(['Meal/Entertain', nan, 'Errand/Supplies', 'Meeting',
#        'Customer Visit', 'Temporary Site', 'Between Offices',
#        'Charity ($)', 'Commute', 'Moving', 'Airport/Travel'], dtype=object)

# %%
data.START.unique()
# Out:
# array(['Fort Pierce', 'West Palm Beach', 'Cary', 'Jamaica', 'New York',
#        'Elmhurst', 'Midtown', 'East Harlem', 'Flatiron District',
#        'Midtown East', 'Hudson Square', 'Lower Manhattan',
#        "Hell's Kitchen", 'Downtown', 'Gulfton', 'Houston', 'Eagan Park',
#        'Morrisville', 'Durham', 'Farmington Woods', 'Whitebridge',
#        'Lake Wellingborough', 'Fayetteville Street', 'Raleigh',
#        'Hazelwood', 'Fairmont', 'Meredith Townes', 'Apex', 'Chapel Hill',
#        'Northwoods', 'Edgehill Farms', 'Tanglewood', 'Preston',
#        'Eastgate', 'East Elmhurst', 'Jackson Heights', 'Long Island City',
#        'Katunayaka', 'Unknown Location', 'Colombo', 'Nugegoda',
#        'Islamabad', 'R?walpindi', 'Noorpur Shahan', 'Heritage Pines',
#        'Westpark Place', 'Waverly Place', 'Wayne Ridge', 'Weston',
#        'East Austin', 'West University', 'South Congress', 'The Drag',
#        'Congress Ave District', 'Red River District', 'Georgian Acres',
# ...

# %%
data.STOP.unique()
# Out:
# array(['Fort Pierce', 'West Palm Beach', 'Palm Beach', 'Cary',
#        'Morrisville', 'New York', 'Queens', 'East Harlem', 'NoMad',
#        'Midtown', 'Midtown East', 'Hudson Square', 'Lower Manhattan',
#        "Hell's Kitchen", 'Queens County', 'Gulfton', 'Downtown',
#        'Houston', 'Jamestown Court', 'Durham', 'Whitebridge',
#        'Lake Wellingborough', 'Raleigh', 'Umstead', 'Hazelwood',
#        'Westpark Place', 'Meredith Townes', 'Leesville Hollow', 'Apex',
#        'Chapel Hill', 'Williamsburg Manor', 'Macgregor Downs',
#        'Edgehill Farms', 'Northwoods', 'Tanglewood', 'Preston',
#        'Walnut Terrace', 'Jackson Heights', 'East Elmhurst',
#        'Midtown West', 'Long Island City', 'Jamaica', 'Unknown Location',
#        'Colombo', 'Nugegoda', 'Katunayaka', 'Islamabad', 'R?walpindi',
#        'Noorpur Shahan', 'Heritage Pines', 'Waverly Place', 'Wayne Ridge',
#        'Depot Historic District', 'Weston', 'West University',
# ...

# %%
print(len(data.START.unique()),len(data.STOP.unique()))
# Out:
# 178 189

# %% [markdown]
# # DATA FILTERING & DATA CLEANING

# %%
data.START.replace(['R?walpindi','South','Kar?chi','nan'],['Rawalpindi','Southside','Karachi','Unknown Location'],\
                   inplace=True)

# %%
len(data.START.unique())
# Out:
# 175

# %%
pd.options.display.max_rows=None

# %%
data.START.value_counts()
# Out:
# Cary                          201
# Unknown Location              148
# Morrisville                    85
# Whitebridge                    68
# Islamabad                      57
# Durham                         37
# Lahore                         36
# Karachi                        31
# Raleigh                        28
# Apex                           17
# Westpark Place                 17
# Berkeley                       16
# Rawalpindi                     16
# Midtown                        14
# Kenner                         11
# Kissimmee                      11
# New Orleans                    10
# Emeryville                     10
# Downtown                        9
# Banner Elk                      8
# Central                         8
# Orlando                         8
# San Francisco                   8
# Colombo                         8
# Edgehill Farms                  8
# The Drag                        7
# Oakland                         7
# ...

# %%
data['START'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30      False
# 31      False
# 32      False
# 33      False
# 34      False
# 35      False
# 36      False
# 37      False
# 38      False
# 39      False
# 40      False
# 41      False
# 42      False
# 43      False
# 44      False
# 45      False
# 46      False
# 47      False
# 48      False
# 49      False
# 50      False
# 51      False
# 52      False
# 53      False
# 54      False
# 55      False
# 56      False
# 57      False
# 58      False
# 59      False
# 60      False
# 61      False
# ...

# %%
data.drop(1155,inplace=True)

# %%
data.tail()
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES         PURPOSE
# 1150           Kar?chi    0.7         Meeting
# 1151  Unknown Location    3.9  Temporary Site
# 1152  Unknown Location   16.2         Meeting
# 1153           Gampaha    6.4  Temporary Site
# 1154         Ilukwatta   48.2  Temporary Site

# %%
data.STOP.replace(['R?walpindi','Kar?chi','nan'],['Rawalpindi','Karachi','Unknown Location'],\
                   inplace=True)

# %%
data.STOP.replace(['South','South Berkeley','Sunnyside'],'Southwest Berkeley',inplace=True)

# %%
data.STOP.value_counts()
# Out:
# Cary                          203
# Unknown Location              149
# Morrisville                    84
# Whitebridge                    65
# Islamabad                      58
# Durham                         36
# Lahore                         36
# Raleigh                        29
# Karachi                        28
# Rawalpindi                     18
# Apex                           17
# Berkeley                       16
# Westpark Place                 16
# Kissimmee                      12
# Midtown                        11
# Edgehill Farms                 10
# Kenner                         10
# New Orleans                    10
# Central                         9
# Emeryville                      9
# Banner Elk                      8
# Oakland                         8
# Colombo                         8
# San Francisco                   8
# Orlando                         7
# Downtown                        7
# The Drag                        7
# ...

# %%
data.head()
# Out:
#          START_DATE          END_DATE  CATEGORY        START             STOP  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
data.PURPOSE.unique()
# Out:
# array(['Meal/Entertain', nan, 'Errand/Supplies', 'Meeting',
#        'Customer Visit', 'Temporary Site', 'Between Offices',
#        'Charity ($)', 'Commute', 'Moving', 'Airport/Travel'], dtype=object)

# %%
data.PURPOSE.replace(['Meal/Entertain','Errand/Supplies','Temporary Site','Charity ($)','Moving','Commute','Airport/Travel'],\
                     ['Entertainment','Meeting','Customer Visit','Charity','Entertainment','Customer Visit','Airport'],\
                    inplace=True)

# %%
data.PURPOSE.unique()
# Out:
# array(['Entertainment', nan, 'Meeting', 'Customer Visit',
#        'Between Offices', 'Charity', 'Airport'], dtype=object)

# %%
data.PURPOSE.value_counts()
# Out:
# Meeting            315
# Entertainment      164
# Customer Visit     152
# Between Offices     18
# Airport              3
# Charity              1
# Name: PURPOSE, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1155 non-null   object
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1155 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
data['START_DATE'] = pd.to_datetime(data['START_DATE'])
data['END_DATE'] = pd.to_datetime(data['END_DATE'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1155 non-null   datetime64[ns]
#  1   END_DATE    1155 non-null   datetime64[ns]
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1155 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: datetime64[ns](2), float64(1), object(4)
# memory usage: 63.3+ KB

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES         PURPOSE
# 0      Fort Pierce    5.1   Entertainment
# 1      Fort Pierce    5.0             NaN
# 2      Fort Pierce    4.8         Meeting
# 3      Fort Pierce    4.7         Meeting
# 4  West Palm Beach   63.7  Customer Visit

# %% [markdown]
# # DATA WRANGLING

# %%
empty = data[(data.START == 'Unknown Location') | (data.STOP == 'Unknown Location')]
empty
# Out:
#               START_DATE            END_DATE  CATEGORY             START  \
# 108  2016-02-16 03:21:00 2016-02-16 04:13:00  Business        Katunayaka
# 109  2016-02-16 08:29:00 2016-02-16 09:34:00  Business  Unknown Location
# 116  2016-02-16 17:40:00 2016-02-16 17:44:00  Business          Nugegoda
# 117  2016-02-17 13:18:00 2016-02-17 14:04:00  Business  Unknown Location
# 121  2016-02-18 08:19:00 2016-02-18 08:27:00  Business  Unknown Location
# 122  2016-02-18 14:03:00 2016-02-18 14:45:00  Business  Unknown Location
# 123  2016-02-18 15:16:00 2016-02-18 15:31:00  Business         Islamabad
# 124  2016-02-18 18:44:00 2016-02-18 18:58:00  Business  Unknown Location
# 125  2016-02-18 19:27:00 2016-02-18 20:08:00  Business         Islamabad
# 126  2016-02-19 09:02:00 2016-02-19 09:14:00  Business  Unknown Location
# 127  2016-02-19 09:21:00 2016-02-19 09:51:00  Business  Unknown Location
# 128  2016-02-19 10:21:00 2016-02-19 10:48:00  Business  Unknown Location
# ...

# %%
len(empty)
# Out:
# 211

# %%
full_empty = data[(data.START == 'Unknown Location') & (data.STOP == 'Unknown Location')]
full_empty.head()
# Out:
#              START_DATE            END_DATE  CATEGORY             START  \
# 121 2016-02-18 08:19:00 2016-02-18 08:27:00  Business  Unknown Location
# 126 2016-02-19 09:02:00 2016-02-19 09:14:00  Business  Unknown Location
# 127 2016-02-19 09:21:00 2016-02-19 09:51:00  Business  Unknown Location
# 135 2016-02-19 20:34:00 2016-02-19 20:51:00  Personal  Unknown Location
# 142 2016-02-20 18:00:00 2016-02-20 18:03:00  Business  Unknown Location
#
#                  STOP  MILES         PURPOSE
# 121  Unknown Location   23.5  Customer Visit
# 126  Unknown Location   18.3         Meeting
# 127  Unknown Location   11.2         Meeting
# 135  Unknown Location    2.5             NaN
# 142  Unknown Location    3.2         Meeting

# %%
len(full_empty)
# Out:
# 86

# %%
full_empty.index
# Out:
# Int64Index([ 121,  126,  127,  135,  142,  143,  148,  149,  153,  657,  658,
#              659,  660,  661,  662,  666,  667,  668,  672,  673,  674,  675,
#              683,  684,  693,  694,  703,  704,  705,  706,  707,  708,  709,
#              710,  713,  714,  727,  740,  744,  747,  749,  751,  752,  753,
#              754,  755,  756,  757,  758,  759,  760,  761,  762,  766,  772,
#              773,  776,  785,  786,  789,  790,  800,  812, 1055, 1056, 1057,
#             1058, 1059, 1063, 1064, 1065, 1066, 1070, 1074, 1079, 1082, 1083,
#             1089, 1090, 1091, 1092, 1093, 1094, 1100, 1101, 1152],
#            dtype='int64')

# %%
for indexes in full_empty.index:
    data.drop(indexes,inplace=True)

# %%
data.PURPOSE.value_counts()
# Out:
# Meeting            297
# Entertainment      164
# Customer Visit     142
# Between Offices     18
# Charity              1
# Airport              1
# Name: PURPOSE, dtype: int64

# %%
data.PURPOSE.isnull().sum()
# Out:
# 446

# %%
purpose_empty = data[data.PURPOSE.isnull()]
purpose_empty.head()
# Out:
#             START_DATE            END_DATE  CATEGORY        START  \
# 1  2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 32 2016-01-19 09:09:00 2016-01-19 09:23:00  Business  Whitebridge
# 85 2016-02-09 10:54:00 2016-02-09 11:07:00  Personal  Whitebridge
# 86 2016-02-09 11:43:00 2016-02-09 11:50:00  Personal   Northwoods
# 87 2016-02-09 13:36:00 2016-02-09 13:52:00  Personal   Tanglewood
#
#                    STOP  MILES PURPOSE
# 1           Fort Pierce    5.0     NaN
# 32  Lake Wellingborough    7.2     NaN
# 85           Northwoods    5.3     NaN
# 86           Tanglewood    3.0     NaN
# 87              Preston    5.1     NaN

# %%
purpose_empty.index
# Out:
# Int64Index([   1,   32,   85,   86,   87,   88,   89,  102,  103,  109,
#             ...
#              999, 1005, 1008, 1018, 1022, 1050, 1051, 1069, 1071, 1143],
#            dtype='int64', length=446)

# %%
len(data)
# Out:
# 1069

# %%
for indexes in purpose_empty.index:
    data.loc[indexes, 'PURPOSE'] = 'Entertainment'

# %%
data.PURPOSE.isnull().sum()
# Out:
# 0

# %%
data.PURPOSE.value_counts()
# Out:
# Entertainment      610
# Meeting            297
# Customer Visit     142
# Between Offices     18
# Charity              1
# Airport              1
# Name: PURPOSE, dtype: int64

# %%
partial_empty = data[(data.START == 'Unknown Location') | (data.STOP == 'Unknown Location')]
partial_empty
# Out:
#               START_DATE            END_DATE  CATEGORY             START  \
# 108  2016-02-16 03:21:00 2016-02-16 04:13:00  Business        Katunayaka
# 109  2016-02-16 08:29:00 2016-02-16 09:34:00  Business  Unknown Location
# 116  2016-02-16 17:40:00 2016-02-16 17:44:00  Business          Nugegoda
# 117  2016-02-17 13:18:00 2016-02-17 14:04:00  Business  Unknown Location
# 122  2016-02-18 14:03:00 2016-02-18 14:45:00  Business  Unknown Location
# 123  2016-02-18 15:16:00 2016-02-18 15:31:00  Business         Islamabad
# 124  2016-02-18 18:44:00 2016-02-18 18:58:00  Business  Unknown Location
# 125  2016-02-18 19:27:00 2016-02-18 20:08:00  Business         Islamabad
# 128  2016-02-19 10:21:00 2016-02-19 10:48:00  Business  Unknown Location
# 131  2016-02-19 12:09:00 2016-02-19 12:27:00  Business         Islamabad
# 132  2016-02-19 16:26:00 2016-02-19 16:45:00  Business  Unknown Location
# 134  2016-02-19 20:08:00 2016-02-19 20:30:00  Personal         Islamabad
# ...

# %%
partial_empty.index
# Out:
# Int64Index([ 108,  109,  116,  117,  122,  123,  124,  125,  128,  131,
#             ...
#             1126, 1128, 1129, 1133, 1134, 1140, 1141, 1143, 1144, 1151],
#            dtype='int64', length=125)

# %%
for index in partial_empty.index:
    temp = data.loc[index, 'START']
    if temp != 'Unknown Location':
        data.loc[index, 'STOP'] = temp
    else:
        temp = data.loc[index, 'STOP']
        data.loc[index, 'START'] = temp

# %%
data.tail(20)
# Out:
#               START_DATE            END_DATE  CATEGORY       START       STOP  \
# 1134 2016-12-29 11:28:00 2016-12-29 12:00:00  Business     Karachi    Karachi
# 1135 2016-12-29 12:25:00 2016-12-29 12:33:00  Business     Karachi    Karachi
# 1136 2016-12-29 13:17:00 2016-12-29 13:24:00  Business     Karachi    Karachi
# 1137 2016-12-29 13:56:00 2016-12-29 14:11:00  Business     Karachi    Karachi
# 1138 2016-12-29 14:42:00 2016-12-29 14:58:00  Business     Karachi    Karachi
# 1139 2016-12-29 15:05:00 2016-12-29 15:16:00  Business     Karachi    Karachi
# 1140 2016-12-29 18:59:00 2016-12-29 19:14:00  Business     Karachi    Karachi
# 1141 2016-12-29 19:50:00 2016-12-29 20:10:00  Business     Karachi    Karachi
# 1142 2016-12-29 20:15:00 2016-12-29 20:45:00  Business     Karachi    Karachi
# 1143 2016-12-29 20:53:00 2016-12-29 21:42:00  Business     Karachi    Karachi
# 1144 2016-12-29 23:14:00 2016-12-29 23:47:00  Business     Karachi    Karachi
# ...

# %%
data['DURATION'] = (data.END_DATE-data.START_DATE).astype('timedelta64[m]')

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES         PURPOSE  DURATION
# 0      Fort Pierce    5.1   Entertainment       6.0
# 1      Fort Pierce    5.0   Entertainment      12.0
# 2      Fort Pierce    4.8         Meeting      13.0
# 3      Fort Pierce    4.7         Meeting      14.0
# 4  West Palm Beach   63.7  Customer Visit      67.0

# %%
bus_dur = data[data.CATEGORY == 'Business']
bus_dur
# Out:
#               START_DATE            END_DATE  CATEGORY  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business
# 5    2016-01-06 17:15:00 2016-01-06 17:19:00  Business
# 6    2016-01-06 17:30:00 2016-01-06 17:35:00  Business
# 7    2016-01-07 13:27:00 2016-01-07 13:33:00  Business
# 8    2016-01-10 08:05:00 2016-01-10 08:25:00  Business
# 9    2016-01-10 12:17:00 2016-01-10 12:44:00  Business
# 10   2016-01-10 15:08:00 2016-01-10 15:51:00  Business
# 11   2016-01-10 18:18:00 2016-01-10 18:53:00  Business
# 12   2016-01-10 19:12:00 2016-01-10 19:32:00  Business
# 13   2016-01-11 08:55:00 2016-01-11 09:21:00  Business
# 14   2016-01-11 11:56:00 2016-01-11 12:03:00  Business
# 15   2016-01-11 13:32:00 2016-01-11 13:46:00  Business
# ...

# %%
per_dur = data[data.CATEGORY == 'Personal']
per_dur
# Out:
#              START_DATE            END_DATE  CATEGORY              START  \
# 85  2016-02-09 10:54:00 2016-02-09 11:07:00  Personal        Whitebridge
# 86  2016-02-09 11:43:00 2016-02-09 11:50:00  Personal         Northwoods
# 87  2016-02-09 13:36:00 2016-02-09 13:52:00  Personal         Tanglewood
# 88  2016-02-09 13:58:00 2016-02-09 14:02:00  Personal            Preston
# 102 2016-02-13 23:45:00 2016-02-14 00:01:00  Personal      East Elmhurst
# 103 2016-02-14 00:50:00 2016-02-14 01:00:00  Personal    Jackson Heights
# 129 2016-02-19 11:20:00 2016-02-19 11:26:00  Personal          Islamabad
# 130 2016-02-19 11:45:00 2016-02-19 11:50:00  Personal          Islamabad
# 134 2016-02-19 20:08:00 2016-02-19 20:30:00  Personal          Islamabad
# 136 2016-02-20 07:59:00 2016-02-20 08:32:00  Personal          Islamabad
# 137 2016-02-20 10:48:00 2016-02-20 10:56:00  Personal          Islamabad
# 138 2016-02-20 11:45:00 2016-02-20 11:53:00  Personal          Islamabad
# ...

# %%
bus_dur.DURATION.value_counts().sort_index().head()
# Out:
# 0.0     2
# 1.0     1
# 2.0     6
# 3.0    10
# 4.0    22
# Name: DURATION, dtype: int64

# %%
per_dur.DURATION.value_counts().sort_index().head()
# Out:
# 4.0    3
# 5.0    5
# 6.0    4
# 7.0    5
# 8.0    4
# Name: DURATION, dtype: int64

# %% [markdown]
# # VISUALISATION OF INSIGHTS

# %%
fig,ax = pyp.subplots(2,1,figsize=(9,8))

ax[0].tick_params(bottom = False, left = False),
ax[1].tick_params(bottom = False,left = False)

for location in ["left","right","bottom","top"]:
    ax[0].spines[location].set_visible(False)
    ax[1].spines[location].set_visible(False)   

ax[0].plot(bus_dur.DURATION.value_counts().sort_index(),color='red')
ax[1].plot(per_dur.DURATION.value_counts().sort_index(),color='darkblue')

ax[0].text(150,40,'NUMBER OF FREQUENCY AGAINST',weight='bold')
ax[0].text(160,35,'DURATION OF UBER TRIP IN MINUTES',weight='bold')
    
ax[1].text(90,5,'NUMBER OF FREQUENCY AGAINST',weight='bold')
ax[1].text(100,4.5,'DURATION OF UBER TRIP IN MINUTES',weight='bold')
pyp.show()

# %%
temp = data[data.PURPOSE == 'Entertainment']
int(sum(temp.MILES))
# Out:
# 4796

# %%
x,y = [],[]
for indexes in data.PURPOSE.value_counts().index:
    temp = data[data.PURPOSE == indexes]
    s = int(sum(temp.MILES))
    x.append(indexes)
    y.append(s)

# %%
x,y
# Out:
# (['Entertainment',
#   'Meeting',
#   'Customer Visit',
#   'Between Offices',
#   'Charity',
#   'Airport'],
#  [4796, 3164, 2667, 197, 15, 4])

# %%
fig,ax = pyp.subplots(1,1,figsize=(8,7))

ax.tick_params(bottom = False, left = False)

for location in ["left","right","bottom","top"]:
    ax.spines[location].set_visible(False)  

colors=['palegreen','skyblue','slategrey','grey','royalblue','navy']
ax.bar(x,y,color=colors)
ax.set_ylabel('Mileage Coverage', fontweight='bold')
ax.set_xticklabels(x,rotation=90)

ax.text(2,4500,'MILEAGE COVERAGE AGAINST TRIPS',weight='bold')
pyp.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_1144\4271539167.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x,rotation=90)

# %%
data.START.value_counts().head(10)
# Out:
# Cary              201
# Morrisville        86
# Islamabad          85
# Whitebridge        68
# Lahore             45
# Karachi            37
# Durham             37
# Rawalpindi         28
# Raleigh            28
# Westpark Place     17
# Name: START, dtype: int64

# %%
temp_01 = data.START.value_counts().index
temp_01 = temp_01[:10]
temp_02 = data.START.value_counts().values
temp_02 = temp_02[:10]

# %%
fig,ax = pyp.subplots(1,1,figsize=(8,7))

ax.tick_params(bottom = False, left = False)

for location in ["left","right","bottom","top"]:
    ax.spines[location].set_visible(False)  

colors=['deepskyblue','darkslategrey','g','b','y','brown','r','grey','purple','navy']
ax.bar(temp_01,temp_02,color=colors)
ax.set_xticklabels(temp_01,rotation=90)

ax.text(1,190,'FREQUENCY OF CITIES AGAINST STARTING TRIPS LOCATIONS',weight='bold')

pyp.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_1144\1527754560.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(temp_01,rotation=90)
